# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

dataset = pd.read_csv("dataset.csv")

input_data = dataset.iloc[:, :-1]
output_data = dataset.iloc[:, -1]

ss = StandardScaler()
input_data = pd.DataFrame(ss.fit_transform(input_data), columns=input_data.columns)

for epoch in range(10):
    print(f"Iteration {epoch + 1}:")

    x_train, x_test, y_train, y_test = train_test_split(input_data, output_data, test_size=0.25)

    knn = KNeighborsClassifier(n_neighbors=10)
    knn.fit(x_train, y_train)

    y_pred_test = knn.predict(x_test)
    test_accuracy = accuracy_score(y_test, y_pred_test)
    print(f'Test accuracy: {test_accuracy * 100:.2f}%')

    y_pred_train = knn.predict(x_train)
    train_accuracy = accuracy_score(y_train, y_pred_train)
    print(f'Train accuracy: {train_accuracy * 100:.2f}%')

    data_point = pd.DataFrame([[0,51,0,0,1,0,1,2,1]], columns=input_data.columns)
    data_point_scaled = ss.transform(data_point)
    prediction = knn.predict(pd.DataFrame(data_point_scaled, columns=input_data.columns))
    print(f'Prediction for data point: {prediction[0]}')

    print("=" * 50)
# Out:
# Iteration 1:
# Test accuracy: 99.60%
# Train accuracy: 99.33%
# Prediction for data point: 0
# ...
# Iteration 2:
# Test accuracy: 99.20%
# Train accuracy: 99.47%
# Prediction for data point: 0
# ...
# Iteration 3:
# Test accuracy: 98.40%
# Train accuracy: 99.73%
# Prediction for data point: 0
# ...
# Iteration 4:
# Test accuracy: 99.20%
# Train accuracy: 99.73%
# Prediction for data point: 0
# ...
# Iteration 5:
# Test accuracy: 99.60%
# Train accuracy: 99.47%
# Prediction for data point: 0
# ...
# Iteration 6:
# Test accuracy: 99.20%
# Train accuracy: 99.47%
# Prediction for data point: 0
# ...
# Iteration 7:
# Test accuracy: 98.40%
# Train accuracy: 99.60%
# Prediction for data point: 0
# ...
# Iteration 8:
# Test accuracy: 98.40%
# Train accuracy: 99.60%
# Prediction for data point: 0
# ...
# Iteration 9:
# Test accuracy: 99.60%
# Train accuracy: 99.73%
# Prediction for data point: 0
# ...
# Iteration 10:
# Test accuracy: 99.60%
# Train accuracy: 99.33%
# Prediction for data point: 0
# ...
