# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

dataset = pd.read_csv("dataset.csv")

print(dataset.head(4))

input_data = dataset.iloc[:, :-1]
output_data = dataset.iloc[:, -1]

ss = StandardScaler()
input_data = pd.DataFrame(ss.fit_transform(input_data), columns=input_data.columns)

print(input_data.shape)

svm = SVC(kernel='linear', probability=True)

for iteration in range(10):
    print(f"Iteration {iteration + 1}:")

    x_train, x_test, y_train, y_test = train_test_split(input_data, output_data, test_size=0.2, random_state=iteration)

    svm.fit(x_train, y_train)

    y_pred_test = svm.predict(x_test)
    test_accuracy = accuracy_score(y_test, y_pred_test)
    print(f'Test accuracy: {test_accuracy * 100:.2f}%')

    y_pred_train = svm.predict(x_train)
    train_accuracy = accuracy_score(y_train, y_pred_train)
    print(f'Train accuracy: {train_accuracy * 100:.2f}%')

    data_point = np.array([[0,29,0,0,0,0,0,2,1]])
    data_point_df = pd.DataFrame(data_point, columns=input_data.columns)
    data_point_scaled = ss.transform(data_point_df)
    prediction = svm.predict(data_point_scaled)
    print(f'Prediction: {prediction[0]}')

    print("=" * 50)
# Out:
#    Gender  Age  NS1  IgG  IgM  Area  AreaType  HouseType  District  Outcome
# 0       0   45    0    0    0     1         0          1         1        0
# 1       1   17    0    0    1     0         1          1         1        0
# 2       0   29    0    0    0     0         0          2         1        0
# 3       0   63    1    1    0     0         1          2         1        1
# (1000, 9)
# Iteration 1:
# Test accuracy: 100.00%
# Train accuracy: 100.00%
# Prediction: 0
# ...
# Iteration 2:
# Test accuracy: 100.00%
# Train accuracy: 100.00%
# Prediction: 0
# ...
# Iteration 3:
# Test accuracy: 100.00%
# Train accuracy: 100.00%
# Prediction: 0
# ...
# Iteration 4:
# Test accuracy: 100.00%
# Train accuracy: 100.00%
# Prediction: 0
# ...
# Iteration 5:
# Test accuracy: 100.00%
# Train accuracy: 100.00%
# Prediction: 0
# ...
# Iteration 6:
# Test accuracy: 100.00%
# Train accuracy: 100.00%
# Prediction: 0
# ...
# Iteration 7:
# Test accuracy: 100.00%
# Train accuracy: 100.00%
# Prediction: 0
# ...
# Iteration 8:
# ...
